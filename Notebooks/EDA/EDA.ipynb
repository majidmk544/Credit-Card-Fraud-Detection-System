# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv(r"C:\Users\MAJID KHAN\Data Science\Projects\CreditCard Fraud\Data\creditcard.csv")

# %%
dataset.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
#
# [3 rows x 31 columns]

# %%
dataset.shape
# Out:
# (194194, 31)

# %%
dataset.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
dataset['Class'].value_counts()
# Out:
# Class
# 0.0    193812
# 1.0       381
# Name: count, dtype: int64

# %%
sns.countplot(x='Class' ,data=dataset)
plt.title('Distribution of Fraud and Legitimate Transactions')
plt.show()

# %%
dataset.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  194194.000000  194194.000000  194194.000000  194194.000000
# mean    68813.763170      -0.115439       0.007428       0.349101
# std     33460.410286       1.887772       1.620690       1.439419
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     43692.000000      -0.965423      -0.576524      -0.289391
# 50%     66070.000000      -0.104569       0.084271       0.514603
# 75%     87110.750000       1.208643       0.784954       1.236743
# max    130474.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  194194.000000  194194.000000  194194.000000  194194.000000
# mean        0.083938      -0.122675       0.049016      -0.056465
# std         1.396242       1.358257       1.307784       1.214478
# min        -5.683171     -42.147898     -26.160506     -43.557242
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194194 entries, 0 to 194193
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    194194 non-null  float64
#  1   V1      194194 non-null  float64
#  2   V2      194194 non-null  float64
#  3   V3      194194 non-null  float64
#  4   V4      194194 non-null  float64
#  5   V5      194194 non-null  float64
#  6   V6      194194 non-null  float64
#  7   V7      194194 non-null  float64
#  8   V8      194194 non-null  float64
#  9   V9      194194 non-null  float64
#  10  V10     194194 non-null  float64
#  11  V11     194194 non-null  float64
#  12  V12     194194 non-null  float64
#  13  V13     194194 non-null  float64
#  14  V14     194194 non-null  float64
#  15  V15     194194 non-null  float64
#  16  V16     194194 non-null  float64
#  17  V17     194194 non-null  float64
#  18  V18     194194 non-null  float64
#  19  V19     194194 non-null  float64
# ...

# %% [markdown]
# # Data Cleaning

# %%
dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
dataset['V24'].mean()
# Out:
# 0.0049143702215516645

# %%
dataset['V24'].fillna(dataset['V24'].mean(), inplace=True)
# Out:
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\407502634.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['V24'].fillna(dataset['V24'].mean(), inplace=True)

# %%
dataset['V25'].fillna(dataset['V25'].mean(), inplace=True)
dataset['V26'].fillna(dataset['V26'].mean(), inplace=True)
dataset['V27'].fillna(dataset['V27'].mean(), inplace=True)
dataset['V28'].fillna(dataset['V28'].mean(), inplace=True)
# Out:
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\3090035886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['V25'].fillna(dataset['V25'].mean(), inplace=True)
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\3090035886.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset['Amount'].median()
# Out:
# 22.9

# %%
dataset['Amount'].fillna(dataset['Amount'].median(), inplace=True)
# Out:
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\2029168884.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Amount'].fillna(dataset['Amount'].median(), inplace=True)

# %%
dataset['Class'].mode()
# Out:
# 0    0.0
# Name: Class, dtype: float64

# %%
dataset['Class'].fillna(dataset['Class'].mode()[0], inplace=True)
# Out:
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\1431106289.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Class'].fillna(dataset['Class'].mode()[0], inplace=True)

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
sns.histplot(dataset['Amount'] ,kde=True)
plt.show()

# %%
dataset.duplicated().sum()
# Out:
# 705

# %%
# Removing Duplicates

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
# Showing Class Distribution

# %%
fraud_count = dataset['Class'].value_counts()
labels = ['Legit', 'Fraud']
sns.barplot(x=labels, y=fraud_count.values)
# Out:
# <Axes: >

# %%
# Analyzing AMOUNT variable by ClASS variable.

# %%
sns.boxplot(x= 'Class', y='Amount', data=dataset, linecolor='red')
plt.title('Trans Amount by Class')
plt.show()

# %%
#For reducing skewness, we need to Scale it.

# %%
from sklearn.preprocessing import RobustScaler

# %%
dataset['Amount'].skew()
# Out:
# 14.770376417885625

# %%
sc= RobustScaler()

# %%
dataset['Scaled_Amount']= sc.fit_transform(dataset[['Amount']])

# %%
dataset.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
#
#         V27       V28  Amount  Class  Scaled_Amount
# 0  0.133558 -0.021053  149.62    0.0       1.731174
# 1 -0.008983  0.014724    2.69    0.0      -0.276889
#
# [2 rows x 32 columns]

# %%
dataset.drop(['Amount'], axis=1, inplace=True)

# %%
dataset.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
#
#         V26       V27       V28  Class  Scaled_Amount
# 0 -0.189115  0.133558 -0.021053    0.0       1.731174
# 1  0.125895 -0.008983  0.014724    0.0      -0.276889
#
# [2 rows x 31 columns]

# %%
dataset['Scaled_Amount'].skew()
# Out:
# 14.770376417885625

# %%
# Transforming Time into Hours

# %%
dataset['Hour'] = dataset['Time'].apply(lambda x: np.floor(x / 3600) % 24)

# %%
dataset.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
#
#         V27       V28  Class  Scaled_Amount  Hour
# 0  0.133558 -0.021053    0.0       1.731174   0.0
# 1 -0.008983  0.014724    0.0      -0.276889   0.0
#
# [2 rows x 32 columns]

# %%
dataset.drop(['Time'], axis=1, inplace=True)

# %%
# Checking Correlation

# %%
corr = dataset.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(corr, cmap='coolwarm', linewidths=0.5,annot=True)
# Out:
# <Axes: >

# %%
frauds = dataset[dataset['Class'] == 1]
legit = dataset[dataset['Class'] == 0]

sns.kdeplot(frauds['V10'], label='Fraud', shade=True)
sns.kdeplot(legit['V10'], label='Legit', shade=True)
plt.legend()
plt.show()
# Out:
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\17621285.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(frauds['V10'], label='Fraud', shade=True)
# C:\Users\MAJID KHAN\AppData\Local\Temp\ipykernel_8984\17621285.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(legit['V10'], label='Legit', shade=True)

# %%
sns.boxplot(x='Class', y='V14', data=dataset)
# Out:
# <Axes: xlabel='Class', ylabel='V14'>

# %%
# Compute correlation with target
corr_matrix = dataset.corr()
target_corr = corr_matrix['Class'].drop('Class').abs().sort_values(ascending=False)

# Display top 10 features
print("Top 10 features by absolute correlation with 'Class':")
print(target_corr.head(10))
# Out:
# Top 10 features by absolute correlation with 'Class':
# V17    0.374547
# V14    0.318423
# V12    0.267821
# V10    0.247280
# V3     0.235449
# V16    0.226580
# V7     0.223140
# V11    0.165758
# V4     0.143704
# V18    0.135578
# Name: Class, dtype: float64

# %%
# Assuming 'df' is your full dataset
top_features = ['V17', 'V14', 'V12', 'V10', 'V3', 'V16', 'V7', 'V11', 'V4', 'V18']

# Add 'Amopunt','Class' columns
selected_columns = top_features + ['Scaled_Amount','Class']

# Create a new DataFrame with only selected columns
df_top_features = dataset[selected_columns]
data= pd.DataFrame(df_top_features)
# Now data is my reduced dataset
data.head(5)
# Out:
#         V17       V14       V12       V10        V3       V16        V7  \
# 0  0.207971 -0.311169 -0.617801  0.090794  2.536347 -0.470401  0.239599
# 1 -0.114805 -0.143772  1.065235 -0.166974  0.166480  0.463917 -0.078803
# 2  1.109969 -0.165946  0.066084  0.207643  1.773209 -2.890083  0.791461
# 3 -0.684093 -0.287924  0.178228 -0.054952  1.792993 -1.059647  0.237609
# 4 -0.237033 -1.119670  0.538196  0.753074  1.548718 -0.451449  0.592941
#
#         V11        V4       V18  Scaled_Amount  Class
# 0 -0.551600  1.378155  0.025791       1.731174    0.0
# 1  1.612727  0.448154 -0.183361      -0.276889    0.0
# 2  0.624501  0.379780 -0.121359       4.861419    0.0
# 3 -0.226487 -0.863291  1.965775       1.374197    0.0
# 4 -0.822843  0.403034 -0.038195       0.642886    0.0

# %%
selected_columns
# Out:
# ['V17',
#  'V14',
#  'V12',
#  'V10',
#  'V3',
#  'V16',
#  'V7',
#  'V11',
#  'V4',
#  'V18',
#  'Scaled_Amount',
#  'Class']

# %%
import joblib
joblib.dump(data, 'C:/Users/MAJID KHAN/Data Science/Projects/CreditCard Fraud/Data/processed_data.pkl')
# Out:
# ['C:/Users/MAJID KHAN/Data Science/Projects/CreditCard Fraud/Data/processed_data.pkl']

# %%
joblib.dump(sc, "scaler.pkl")
# Out:
# ['scaler.pkl']
